# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('carsales.csv')
df
# Out:
#              Make    Year      Price  Milage  FuelType  \
# 0          Toyota  2010.0  2500000.0    18.0    Petrol
# 1           Honda  2012.0  2000000.0    20.0    Diesel
# 2            Ford  2015.0  1800000.0    22.0  Electric
# 3       Chevrolet  2018.0  2200000.0    25.0       CNG
# 4      Volkswagen  2022.0        NaN    24.0    Hybrid
# 5             NaN  2022.0  2500000.0    18.0    Petrol
# 6             BMW  2023.0  2000000.0    20.0    Diesel
# 7            Audi  2000.0  1800000.0    22.0  Electric
# 8   Mercedes-Benz  2000.0  2200000.0    25.0       CNG
# 9             NaN  2015.0        NaN    24.0    Hybrid
# 10         Toyota     NaN  2500000.0    18.0    Petrol
# 11          Honda  2019.0  2000000.0    20.0    Diesel
# 12           Ford  2022.0  1800000.0    22.0  Electric
# 13      Chevrolet  2019.0  2200000.0     NaN       CNG
# 14     Volkswagen  2018.0  2500000.0    24.0    Hybrid
# 15         Nissan  2018.0  2000000.0    18.0    Petrol
# ...

# %%
r = df.columns
r
# Out:
# Index(['Make', 'Year', 'Price', 'Milage', 'FuelType', 'BodyType',
#        'EngineSize'],
#       dtype='object')

# %%
n = df['Price'].value_counts()
n

raj = np.median(n)
raj
# Out:
# 7.0

# %%
raj = df.groupby('Make')['Milage'].mean()
raj
# Out:
# Make
# Audi             21.333333
# BMW              19.333333
# Chevrolet        24.666667
# Ford             22.000000
# Honda            20.000000
# Hyundai          24.500000
# Mercedes-Benz    23.500000
# Nissan           18.000000
# Toyota           19.500000
# Volkswagen       24.000000
# Name: Milage, dtype: float64

# %%
plt.plot(df['Year'],df['Price'], marker='o', linestyle='-')
plt.title("Line Chart")
plt.xlabel("Year")
plt.ylabel("Price")
plt.grid(True)
plt.show()

# %%
r = df[df['FuelType']=='Diesel'].head(5)
r
# Out:
#      Make    Year      Price  Milage FuelType                     BodyType  \
# 1   Honda  2012.0  2000000.0    20.0   Diesel  SUV (Sport Utility Vehicle)
# 6     BMW  2023.0  2000000.0    20.0   Diesel                        Truck
# 11  Honda  2019.0  2000000.0    20.0   Diesel  SUV (Sport Utility Vehicle)
# 16    BMW  2018.0  1800000.0    20.0   Diesel                        Truck
# 21  Honda  2019.0  2200000.0    20.0   Diesel  SUV (Sport Utility Vehicle)
#
#    EngineSize
# 1       1.5 L
# 6       4.0 L
# 11      1.5 L
# 16      4.0 L
# 21      1.5 L

# %%
n = np.sum(df['Milage'])
n
# Out:
# 650.0

# %%
plt.boxplot(df['Price'])
plt.title("Box Plot")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(True)
plt.show()

# %%
df['EngineSize'] = df['EngineSize'].str.replace(r'\D','').astype(int)
# Out:
# <ipython-input-43-ea8ea4bac7cf>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['EngineSize'] = df['EngineSize'].str.replace(r'\D','').astype(int)

# %%
df['EngineSize'] = df['EngineSize'].astype(int)

# %%
neel = np.mean(df['EngineSize'])
neel
# Out:
# 30.735294117647058

# %%
raj = df['EngineSize'].head(10)

plt.pie(raj,autopct='%1.1f%%', startangle=90)
plt.title("PIE CHART")
plt.show()

# %%
df[df['Milage']<50000].tail(5)
# Out:
#              Make    Year      Price  Milage FuelType   BodyType  EngineSize
# 28  Mercedes-Benz  2019.0  2500000.0    22.0      CNG    Minivan          50
# 29        Hyundai  2018.0  2000000.0    25.0   Hybrid     Pickup          55
# 30         Toyota  2018.0  1800000.0    24.0      NaN      Sedan          10
# 32           Ford  2020.0  1500000.0    22.0      NaN  Hatchback          20
# 33      Chevrolet  2022.0  1200000.0    24.0   Petrol      Coupe          25
