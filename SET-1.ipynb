# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('carsales.csv')
df
# Out:
#              Make    Year      Price  Milage  FuelType  \
# 0          Toyota  2010.0  2500000.0    18.0    Petrol
# 1           Honda  2012.0  2000000.0    20.0    Diesel
# 2            Ford  2015.0  1800000.0    22.0  Electric
# 3       Chevrolet  2018.0  2200000.0    25.0       CNG
# 4      Volkswagen  2022.0        NaN    24.0    Hybrid
# 5             NaN  2022.0  2500000.0    18.0    Petrol
# 6             BMW  2023.0  2000000.0    20.0    Diesel
# 7            Audi  2000.0  1800000.0    22.0  Electric
# 8   Mercedes-Benz  2000.0  2200000.0    25.0       CNG
# 9             NaN  2015.0        NaN    24.0    Hybrid
# 10         Toyota     NaN  2500000.0    18.0    Petrol
# 11          Honda  2019.0  2000000.0    20.0    Diesel
# 12           Ford  2022.0  1800000.0    22.0  Electric
# 13      Chevrolet  2019.0  2200000.0     NaN       CNG
# 14     Volkswagen  2018.0  2500000.0    24.0    Hybrid
# 15         Nissan  2018.0  2000000.0    18.0    Petrol
# ...

# %%
que1 = df['Make'].mode()
que1
# Out:
# 0    Chevrolet
# 1         Ford
# 2        Honda
# 3       Toyota
# Name: Make, dtype: object

# %%
median_prices = df.groupby('Year')['Price'].median()
median_prices
# Out:
# Year
# 2000.0    2000000.0
# 2010.0    2500000.0
# 2012.0    2000000.0
# 2015.0    2200000.0
# 2018.0    2000000.0
# 2019.0    2200000.0
# 2020.0    1850000.0
# 2022.0    1800000.0
# 2023.0    2000000.0
# Name: Price, dtype: float64

# %%
plt.scatter(df['Price'],df['Milage'],linewidths=2,marker=8)
plt.title("Scatter Plot")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(True)
plt.show()

# %%
n = df[df['FuelType']=='Petrol'].head(5)
n
# Out:
#       Make    Year      Price  Milage FuelType BodyType EngineSize
# 0   Toyota  2010.0  2500000.0    18.0   Petrol    Sedan      1.0 L
# 5      NaN  2022.0  2500000.0    18.0   Petrol    Wagon      3.5 L
# 10  Toyota     NaN  2500000.0    18.0   Petrol    Sedan      1.0 L
# 15  Nissan  2018.0  2000000.0    18.0   Petrol    Wagon      3.5 L
# 20  Toyota  2022.0  1800000.0    18.0   Petrol    Sedan      1.0 L

# %%
raj = df.isnull().sum()
raj
# Out:
# Make          2
# Year          3
# Price         4
# Milage        4
# FuelType      2
# BodyType      1
# EngineSize    0
# dtype: int64

# %%
raj = df['BodyType'].value_counts()
raj

plt.bar(raj.index,raj)
plt.title("Bar Chart")
plt.xlabel("BodyType")
plt.ylabel("Index Value")
plt.grid('Y-axis')
plt.show()

# %%
df['EngineSize'] = df['EngineSize'].str.replace(r'\D','').astype(int)
# Out:
# <ipython-input-42-ea8ea4bac7cf>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['EngineSize'] = df['EngineSize'].str.replace(r'\D','').astype(int)

# %%
df['EngineSize'] = df['EngineSize'].astype(int)

# %%
raj = np.std(df['EngineSize'])
raj
# Out:
# 14.45746056850806

# %%
plt.hist(df['Price'])
plt.title("HostoGram")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.grid(True)
plt.show()

# %%
df[df['Year']>=2015].tail(5)
# Out:
#          Make    Year      Price  Milage FuelType   BodyType  EngineSize
# 29    Hyundai  2018.0  2000000.0    25.0   Hybrid     Pickup          55
# 30     Toyota  2018.0  1800000.0    24.0      NaN      Sedan          10
# 31      Honda  2020.0  2200000.0     NaN      CNG        NaN          15
# 32       Ford  2020.0  1500000.0    22.0      NaN  Hatchback          20
# 33  Chevrolet  2022.0  1200000.0    24.0   Petrol      Coupe          25
