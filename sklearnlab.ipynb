# %%
# NOW WE ARE STARTING MLP -> ML LIBRARY
# 1)UNSUPERVISED=UNLABELED DATA
# A.CLUSTERING=GROUPS WITH IDENTICAL DATA[EX:FRUITS,PEOPLE,TREES]
# 2)SUPERVISED=LABELLED DATA
# A.REGRESION=continuos frequency[ex:temperature] -----B.CLASSFICATION=categorized[ex:loan aplication]
# 3)REINFOREMENT=MACHINE LEARNS FROM ITS OWN [AWARD/PUNISHMENT]


#  2 types of variables in supervied learning: x->independent(labelled data) y->dependent(target variable)
# [y=scoring of marks dependent on x=amount of study]

# two types of data
# 1.train data-> 80% from which machine is trained
# 2.test data->20% for which machine is to be tested

# function= split generates 4 variables - 1.xtrain 2.ytrain 3.xtest 4.ytest
# split(x,y,testsize=0.5)[testsize-amount data to be preserved remaining wil be go for training]
# function : fit()->used for training data
# fit(x_train,y_train)
# function used for testing -> predict
# predict(xtest)
# answer available thats why it is -> supervised learning
# score function used for generating acuracy
# score(output_of_predict)

# steps 1)split 2)fit 3)predict 4)score
